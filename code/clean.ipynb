# %%
import numpy as np
import pandas as pd
import re

# %%
attacks = pd.read_csv("attacks.csv", encoding='latin-1')
attacks
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 25718              NaN                             NaN          NaN
# 25719              NaN                             NaN          NaN
# 25720              NaN                             NaN          NaN
# 25721              NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
#
#                   Name Sex   ...         Species   \
# 0          Julie Wolfe    F  ...      White shark
# 1      Adyson McNeely     F  ...              NaN
# 2          John Denges    M  ...              NaN
# 3                 male    M  ...        2 m shark
# 4       Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                ...  ...  ...              ...
# 25718              NaN  NaN  ...              NaN
# 25719              NaN  NaN  ...              NaN
# 25720              NaN  NaN  ...              NaN
# 25721              NaN  NaN  ...              NaN
# 25722              NaN  NaN  ...              NaN
#
#                Investigator or Source                       pdf  \
# 0                    R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1      K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2      K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3                      B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4                           A .Kipper      2018.06.04-Ramos.pdf
# ...                               ...                       ...
# 25718                             NaN                       NaN
# 25719                             NaN                       NaN
# 25720                             NaN                       NaN
# 25721                             NaN                       NaN
# 25722                             NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 25718                                                NaN
# 25719                                                NaN
# 25720                                                NaN
# 25721                                                NaN
# 25722                                                NaN
#
#                                                     href Case Number.1  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                  ...           ...
# 25718                                                NaN           NaN
# 25719                                                NaN           NaN
# 25720                                                NaN           NaN
# 25721                                                NaN           NaN
# 25722                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0        2018.06.25         6303.0         NaN         NaN
# 1        2018.06.18         6302.0         NaN         NaN
# 2        2018.06.09         6301.0         NaN         NaN
# 3        2018.06.08         6300.0         NaN         NaN
# 4        2018.06.04         6299.0         NaN         NaN
# ...             ...            ...         ...         ...
# 25718           NaN            NaN         NaN         NaN
# 25719           NaN            NaN         NaN         NaN
# 25720           NaN            NaN         NaN         NaN
# 25721           NaN            NaN         NaN         NaN
# 25722           NaN            NaN         NaN         NaN
#
# [25723 rows x 24 columns]

# %% [markdown]
# Primero voy a ver el nombre de las columnas y el número de nulos que contienen

# %%
name_columns = list(attacks.columns)
print(name_columns)
# Out:
# ['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location', 'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time', 'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href', 'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22', 'Unnamed: 23']

# %%
attacks.isnull().sum()
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %% [markdown]
# Elimino las dos ultimas columnas ya que casi todos sus valores son nulos

# %%
attacks_clean = attacks.drop(columns = ["Unnamed: 22", "Unnamed: 23"])

# %%
attacks_clean.isnull().sum()
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# dtype: int64

# %% [markdown]
# Las ultimas filas parecen contener bastantes nulls. Voy a trasponer el DataFrame para analizar las filas como columnas y ver cuantos Nulls contienen

# %%
attacks_clean_Transp = attacks_clean.T
attacks_clean_Transp
# Out:
#                                                                     0      \
# Case Number                                                    2018.06.25
# Date                                                          25-Jun-2018
# Year                                                                 2018
# Type                                                              Boating
# Country                                                               USA
# Area                                                           California
# Location                                      Oceanside, San Diego County
# Activity                                                         Paddling
# Name                                                          Julie Wolfe
# Sex                                                                     F
# Age                                                                    57
# Injury                  No injury to occupant, outrigger canoe and pad...
# Fatal (Y/N)                                                             N
# Time                                                                18h00
# Species                                                       White shark
# Investigator or Source                                   R. Collier, GSAF
# pdf                                                  2018.06.25-Wolfe.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                  2018.06.25
# Case Number.2                                                  2018.06.25
# original order                                                       6303
#
#                                                                     1      \
# Case Number                                                    2018.06.18
# Date                                                          18-Jun-2018
# Year                                                                 2018
# Type                                                           Unprovoked
# Country                                                               USA
# Area                                                              Georgia
# Location                                   St. Simon Island, Glynn County
# Activity                                                         Standing
# Name                                                      Adyson McNeely
# Sex                                                                     F
# Age                                                                    11
# Injury                                         Minor injury to left thigh
# Fatal (Y/N)                                                             N
# Time                                                        14h00  -15h00
# Species                                                               NaN
# Investigator or Source                     K.McMurray, TrackingSharks.com
# pdf                                                2018.06.18-McNeely.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                  2018.06.18
# Case Number.2                                                  2018.06.18
# original order                                                       6302
#
#                                                                     2      \
# Case Number                                                    2018.06.09
# Date                                                          09-Jun-2018
# Year                                                                 2018
# Type                                                              Invalid
# Country                                                               USA
# Area                                                               Hawaii
# Location                                                     Habush, Oahu
# Activity                                                          Surfing
# Name                                                          John Denges
# Sex                                                                     M
# Age                                                                    48
# Injury                       Injury to left lower leg from surfboard skeg
# Fatal (Y/N)                                                             N
# Time                                                                07h45
# Species                                                               NaN
# Investigator or Source                     K.McMurray, TrackingSharks.com
# pdf                                                 2018.06.09-Denges.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                  2018.06.09
# Case Number.2                                                  2018.06.09
# original order                                                       6301
#
#                                                                     3      \
# Case Number                                                    2018.06.08
# Date                                                          08-Jun-2018
# Year                                                                 2018
# Type                                                           Unprovoked
# Country                                                         AUSTRALIA
# Area                                                      New South Wales
# Location                                               Arrawarra Headland
# Activity                                                          Surfing
# Name                                                                 male
# Sex                                                                     M
# Age                                                                   NaN
# Injury                                          Minor injury to lower leg
# Fatal (Y/N)                                                             N
# Time                                                                  NaN
# Species                                                         2 m shark
# Investigator or Source                                     B. Myatt, GSAF
# pdf                                              2018.06.08-Arrawarra.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                  2018.06.08
# Case Number.2                                                  2018.06.08
# original order                                                       6300
#
#                                                                     4      \
# Case Number                                                    2018.06.04
# Date                                                          04-Jun-2018
# Year                                                                 2018
# Type                                                             Provoked
# Country                                                            MEXICO
# Area                                                               Colima
# Location                                                         La Ticla
# Activity                                                      Free diving
# Name                                                       Gustavo Ramos
# Sex                                                                     M
# Age                                                                   NaN
# Injury                  Lacerations to leg & hand shark PROVOKED INCIDENT
# Fatal (Y/N)                                                             N
# Time                                                                  NaN
# Species                                                   Tiger shark, 3m
# Investigator or Source                                          A .Kipper
# pdf                                                  2018.06.04-Ramos.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                  2018.06.04
# Case Number.2                                                  2018.06.04
# original order                                                       6299
#
#                                                                     5      \
# Case Number                                                  2018.06.03.b
# Date                                                          03-Jun-2018
# Year                                                                 2018
# Type                                                           Unprovoked
# Country                                                         AUSTRALIA
# Area                                                      New South Wales
# Location                                               Flat Rock, Ballina
# Activity                                                     Kite surfing
# Name                                                              Chris
#
# Sex                                                                     M
# Age                                                                   NaN
# Injury                                            No injury, board bitten
# Fatal (Y/N)                                                             N
# Time                                                                  NaN
# Species                                                               NaN
# Investigator or Source                          Daily Telegraph, 6/4/2018
# pdf                                             2018.06.03.b-FlatRock.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                2018.06.03.b
# Case Number.2                                                2018.06.03.b
# original order                                                       6298
#
#                                                                     6      \
# Case Number                                                  2018.06.03.a
# Date                                                          03-Jun-2018
# Year                                                                 2018
# Type                                                           Unprovoked
# Country                                                            BRAZIL
# Area                                                           Pernambuco
# Location                                            Piedade Beach, Recife
# Activity                                                         Swimming
# Name                                               Jose Ernesto da Silva
# Sex                                                                     M
# Age                                                                    18
# Injury                                                              FATAL
# Fatal (Y/N)                                                             Y
# Time                                                       Late afternoon
# Species                                                       Tiger shark
# Investigator or Source                     Diario de Pernambuco, 6/4/2018
# pdf                                              2018.06.03.a-daSilva.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                2018.06.03.a
# Case Number.2                                                2018.06.03.a
# original order                                                       6297
#
#                                                                     7      \
# Case Number                                                    2018.05.27
# Date                                                          27-May-2018
# Year                                                                 2018
# Type                                                           Unprovoked
# Country                                                               USA
# Area                                                              Florida
# Location                Lighhouse Point Park, Ponce Inlet, Volusia County
# Activity                                                          Fishing
# Name                                                                 male
# Sex                                                                     M
# Age                                                                    52
# Injury                            Minor injury to foot. PROVOKED INCIDENT
# Fatal (Y/N)                                                             N
# Time                                                                  NaN
# Species                                                   Lemon shark, 3'
# Investigator or Source                    K. McMurray, TrackingSharks.com
# pdf                                                  2018.05.27-Ponce.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                  2018.05.27
# Case Number.2                                                  2018.05.27
# original order                                                       6296
#
#                                                                     8      \
# Case Number                                                  2018.05.26.b
# Date                                                          26-May-2018
# Year                                                                 2018
# Type                                                           Unprovoked
# Country                                                               USA
# Area                                                              Florida
# Location                                     Cocoa Beach, Brevard  County
# Activity                                                          Walking
# Name                                                            Cody High
# Sex                                                                     M
# Age                                                                    15
# Injury                                              Lower left leg bitten
# Fatal (Y/N)                                                             N
# Time                                                                17h00
# Species                                                    Bull shark, 6'
# Investigator or Source                     K.McMurray, TrackingSharks.com
# pdf                                                 2018.05.26.b-High.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                2018.05.26.b
# Case Number.2                                                2018.05.26.b
# original order                                                       6295
#
#                                                                     9      \
# Case Number                                                  2018.05.26.a
# Date                                                          26-May-2018
# Year                                                                 2018
# Type                                                           Unprovoked
# Country                                                               USA
# Area                                                              Florida
# Location                                    Daytona Beach, Volusia County
# Activity                                                         Standing
# Name                                                                 male
# Sex                                                                     M
# Age                                                                    12
# Injury                                               Minor injury to foot
# Fatal (Y/N)                                                             N
# Time                                                                14h00
# Species                                                               NaN
# Investigator or Source                   K. McMurray, Tracking Sharks.com
# pdf                                         2018.05.26.a-DaytonaBeach.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                2018.05.26.a
# Case Number.2                                                2018.05.26.a
# original order                                                       6294
#
#                         ... 25713 25714 25715 25716 25717 25718 25719 25720  \
# Case Number             ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Date                    ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Year                    ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Type                    ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Country                 ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Area                    ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Location                ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Activity                ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Name                    ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Sex                     ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Age                     ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Injury                  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Fatal (Y/N)             ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Time                    ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Species                 ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Investigator or Source  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# pdf                     ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# href formula            ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# href                    ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Case Number.1           ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Case Number.2           ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# original order          ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                        25721 25722
# Case Number              NaN    xx
# Date                     NaN   NaN
# Year                     NaN   NaN
# Type                     NaN   NaN
# Country                  NaN   NaN
# Area                     NaN   NaN
# Location                 NaN   NaN
# Activity                 NaN   NaN
# Name                     NaN   NaN
# Sex                      NaN   NaN
# Age                      NaN   NaN
# Injury                   NaN   NaN
# Fatal (Y/N)              NaN   NaN
# Time                     NaN   NaN
# Species                  NaN   NaN
# Investigator or Source   NaN   NaN
# pdf                      NaN   NaN
# href formula             NaN   NaN
# href                     NaN   NaN
# Case Number.1            NaN   NaN
# Case Number.2            NaN   NaN
# original order           NaN   NaN
#
# [22 rows x 25723 columns]

# %%
attacks_clean_Transp.isnull().sum()
# Out:
# 0         0
# 1         1
# 2         1
# 3         2
# 4         2
#          ..
# 25718    22
# 25719    22
# 25720    22
# 25721    22
# 25722    21
# Length: 25723, dtype: int64

# %%
morethan20Nulls = attacks_clean_Transp.isnull().sum()[attacks_clean_Transp.isnull().sum() > 20].index
morethan20Nulls
# Out:
# Int64Index([ 6309,  6310,  6311,  6312,  6313,  6314,  6315,  6316,  6317,
#              6318,
#             ...
#             25713, 25714, 25715, 25716, 25717, 25718, 25719, 25720, 25721,
#             25722],
#            dtype='int64', length=19414)

# %%
attacks_clean_Transp = attacks_clean_Transp.drop(columns=morethan20Nulls)
attacks_clean_Transp
# Out:
#                                                                      0     \
# Case Number                                                    2018.06.25
# Date                                                          25-Jun-2018
# Year                                                                 2018
# Type                                                              Boating
# Country                                                               USA
# Area                                                           California
# Location                                      Oceanside, San Diego County
# Activity                                                         Paddling
# Name                                                          Julie Wolfe
# Sex                                                                     F
# Age                                                                    57
# Injury                  No injury to occupant, outrigger canoe and pad...
# Fatal (Y/N)                                                             N
# Time                                                                18h00
# Species                                                       White shark
# Investigator or Source                                   R. Collier, GSAF
# pdf                                                  2018.06.25-Wolfe.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                  2018.06.25
# Case Number.2                                                  2018.06.25
# original order                                                       6303
#
#                                                                      1     \
# Case Number                                                    2018.06.18
# Date                                                          18-Jun-2018
# Year                                                                 2018
# Type                                                           Unprovoked
# Country                                                               USA
# Area                                                              Georgia
# Location                                   St. Simon Island, Glynn County
# Activity                                                         Standing
# Name                                                      Adyson McNeely
# Sex                                                                     F
# Age                                                                    11
# Injury                                         Minor injury to left thigh
# Fatal (Y/N)                                                             N
# Time                                                        14h00  -15h00
# Species                                                               NaN
# Investigator or Source                     K.McMurray, TrackingSharks.com
# pdf                                                2018.06.18-McNeely.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                  2018.06.18
# Case Number.2                                                  2018.06.18
# original order                                                       6302
#
#                                                                      2     \
# Case Number                                                    2018.06.09
# Date                                                          09-Jun-2018
# Year                                                                 2018
# Type                                                              Invalid
# Country                                                               USA
# Area                                                               Hawaii
# Location                                                     Habush, Oahu
# Activity                                                          Surfing
# Name                                                          John Denges
# Sex                                                                     M
# Age                                                                    48
# Injury                       Injury to left lower leg from surfboard skeg
# Fatal (Y/N)                                                             N
# Time                                                                07h45
# Species                                                               NaN
# Investigator or Source                     K.McMurray, TrackingSharks.com
# pdf                                                 2018.06.09-Denges.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                  2018.06.09
# Case Number.2                                                  2018.06.09
# original order                                                       6301
#
#                                                                      3     \
# Case Number                                                    2018.06.08
# Date                                                          08-Jun-2018
# Year                                                                 2018
# Type                                                           Unprovoked
# Country                                                         AUSTRALIA
# Area                                                      New South Wales
# Location                                               Arrawarra Headland
# Activity                                                          Surfing
# Name                                                                 male
# Sex                                                                     M
# Age                                                                   NaN
# Injury                                          Minor injury to lower leg
# Fatal (Y/N)                                                             N
# Time                                                                  NaN
# Species                                                         2 m shark
# Investigator or Source                                     B. Myatt, GSAF
# pdf                                              2018.06.08-Arrawarra.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                  2018.06.08
# Case Number.2                                                  2018.06.08
# original order                                                       6300
#
#                                                                      4     \
# Case Number                                                    2018.06.04
# Date                                                          04-Jun-2018
# Year                                                                 2018
# Type                                                             Provoked
# Country                                                            MEXICO
# Area                                                               Colima
# Location                                                         La Ticla
# Activity                                                      Free diving
# Name                                                       Gustavo Ramos
# Sex                                                                     M
# Age                                                                   NaN
# Injury                  Lacerations to leg & hand shark PROVOKED INCIDENT
# Fatal (Y/N)                                                             N
# Time                                                                  NaN
# Species                                                   Tiger shark, 3m
# Investigator or Source                                          A .Kipper
# pdf                                                  2018.06.04-Ramos.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                  2018.06.04
# Case Number.2                                                  2018.06.04
# original order                                                       6299
#
#                                                                      5     \
# Case Number                                                  2018.06.03.b
# Date                                                          03-Jun-2018
# Year                                                                 2018
# Type                                                           Unprovoked
# Country                                                         AUSTRALIA
# Area                                                      New South Wales
# Location                                               Flat Rock, Ballina
# Activity                                                     Kite surfing
# Name                                                              Chris
#
# Sex                                                                     M
# Age                                                                   NaN
# Injury                                            No injury, board bitten
# Fatal (Y/N)                                                             N
# Time                                                                  NaN
# Species                                                               NaN
# Investigator or Source                          Daily Telegraph, 6/4/2018
# pdf                                             2018.06.03.b-FlatRock.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                2018.06.03.b
# Case Number.2                                                2018.06.03.b
# original order                                                       6298
#
#                                                                      6     \
# Case Number                                                  2018.06.03.a
# Date                                                          03-Jun-2018
# Year                                                                 2018
# Type                                                           Unprovoked
# Country                                                            BRAZIL
# Area                                                           Pernambuco
# Location                                            Piedade Beach, Recife
# Activity                                                         Swimming
# Name                                               Jose Ernesto da Silva
# Sex                                                                     M
# Age                                                                    18
# Injury                                                              FATAL
# Fatal (Y/N)                                                             Y
# Time                                                       Late afternoon
# Species                                                       Tiger shark
# Investigator or Source                     Diario de Pernambuco, 6/4/2018
# pdf                                              2018.06.03.a-daSilva.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                2018.06.03.a
# Case Number.2                                                2018.06.03.a
# original order                                                       6297
#
#                                                                      7     \
# Case Number                                                    2018.05.27
# Date                                                          27-May-2018
# Year                                                                 2018
# Type                                                           Unprovoked
# Country                                                               USA
# Area                                                              Florida
# Location                Lighhouse Point Park, Ponce Inlet, Volusia County
# Activity                                                          Fishing
# Name                                                                 male
# Sex                                                                     M
# Age                                                                    52
# Injury                            Minor injury to foot. PROVOKED INCIDENT
# Fatal (Y/N)                                                             N
# Time                                                                  NaN
# Species                                                   Lemon shark, 3'
# Investigator or Source                    K. McMurray, TrackingSharks.com
# pdf                                                  2018.05.27-Ponce.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                  2018.05.27
# Case Number.2                                                  2018.05.27
# original order                                                       6296
#
#                                                                      8     \
# Case Number                                                  2018.05.26.b
# Date                                                          26-May-2018
# Year                                                                 2018
# Type                                                           Unprovoked
# Country                                                               USA
# Area                                                              Florida
# Location                                     Cocoa Beach, Brevard  County
# Activity                                                          Walking
# Name                                                            Cody High
# Sex                                                                     M
# Age                                                                    15
# Injury                                              Lower left leg bitten
# Fatal (Y/N)                                                             N
# Time                                                                17h00
# Species                                                    Bull shark, 6'
# Investigator or Source                     K.McMurray, TrackingSharks.com
# pdf                                                 2018.05.26.b-High.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                2018.05.26.b
# Case Number.2                                                2018.05.26.b
# original order                                                       6295
#
#                                                                      9     \
# Case Number                                                  2018.05.26.a
# Date                                                          26-May-2018
# Year                                                                 2018
# Type                                                           Unprovoked
# Country                                                               USA
# Area                                                              Florida
# Location                                    Daytona Beach, Volusia County
# Activity                                                         Standing
# Name                                                                 male
# Sex                                                                     M
# Age                                                                    12
# Injury                                               Minor injury to foot
# Fatal (Y/N)                                                             N
# Time                                                                14h00
# Species                                                               NaN
# Investigator or Source                   K. McMurray, Tracking Sharks.com
# pdf                                         2018.05.26.a-DaytonaBeach.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                2018.05.26.a
# Case Number.2                                                2018.05.26.a
# original order                                                       6294
#
#                         ...  \
# Case Number             ...
# Date                    ...
# Year                    ...
# Type                    ...
# Country                 ...
# Area                    ...
# Location                ...
# Activity                ...
# Name                    ...
# Sex                     ...
# Age                     ...
# Injury                  ...
# Fatal (Y/N)             ...
# Time                    ...
# Species                 ...
# Investigator or Source  ...
# pdf                     ...
# href formula            ...
# href                    ...
# Case Number.1           ...
# Case Number.2           ...
# original order          ...
#
#                                                                      6299  \
# Case Number                                                       ND.0003
# Date                                                            1900-1905
# Year                                                                    0
# Type                                                           Unprovoked
# Country                                                               USA
# Area                                                       North Carolina
# Location                                                   Ocracoke Inlet
# Activity                                                         Swimming
# Name                                                Coast Guard personnel
# Sex                                                                     M
# Age                                                                   NaN
# Injury                                                              FATAL
# Fatal (Y/N)                                                             Y
# Time                                                                  NaN
# Species                                                               NaN
# Investigator or Source               F. Schwartz, p.23; C. Creswell, GSAF
# pdf                                        ND-0003-Ocracoke_1900-1905.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                     ND.0003
# Case Number.2                                                     ND.0003
# original order                                                          4
#
#                                                                      6300  \
# Case Number                                                       ND.0002
# Date                                                            1883-1889
# Year                                                                    0
# Type                                                           Unprovoked
# Country                                                            PANAMA
# Area                                                                  NaN
# Location                                             Panama Bay 8ºN, 79ºW
# Activity                                                              NaN
# Name                                                      Jules Patterson
# Sex                                                                     M
# Age                                                                   NaN
# Injury                                                              FATAL
# Fatal (Y/N)                                                             Y
# Time                                                                  NaN
# Species                                                               NaN
# Investigator or Source                                The Sun, 10/20/1938
# pdf                                            ND-0002-JulesPatterson.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                     ND.0002
# Case Number.2                                                     ND.0002
# original order                                                          3
#
#                                                                      6301  \
# Case Number                                                       ND.0001
# Date                                                            1845-1853
# Year                                                                    0
# Type                                                           Unprovoked
# Country                                                CEYLON (SRI LANKA)
# Area                                                     Eastern Province
# Location                              Below the English fort, Trincomalee
# Activity                                                         Swimming
# Name                                                                 male
# Sex                                                                     M
# Age                                                                    15
# Injury                  FATAL. "Shark bit him in half, carrying away t...
# Fatal (Y/N)                                                             Y
# Time                                                                  NaN
# Species                                                               NaN
# Investigator or Source                                         S.W. Baker
# pdf                                                    ND-0001-Ceylon.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                     ND.0001
# Case Number.2                                                     ND.0001
# original order                                                          2
#
#                         6302  6303  6304  6305  6306  6307  6308
# Case Number                0     0     0     0     0     0     0
# Date                     NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Year                     NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Type                     NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Country                  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Area                     NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Location                 NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Activity                 NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Name                     NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Sex                      NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Age                      NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Injury                   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Fatal (Y/N)              NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Time                     NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Species                  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Investigator or Source   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# pdf                      NaN   NaN   NaN   NaN   NaN   NaN   NaN
# href formula             NaN   NaN   NaN   NaN   NaN   NaN   NaN
# href                     NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Case Number.1            NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Case Number.2            NaN   NaN   NaN   NaN   NaN   NaN   NaN
# original order          6304  6305  6306  6307  6308  6309  6310
#
# [22 rows x 6309 columns]

# %% [markdown]
# Como se ve en el display del DataFrame las ultimas columnas siguen teniendo bastante nulos. Voy a eliminar los que sean = 20

# %%
attacks_clean_Transp.isnull().sum()
# Out:
# 0        0
# 1        1
# 2        1
# 3        2
# 4        2
#         ..
# 6304    20
# 6305    20
# 6306    20
# 6307    20
# 6308    20
# Length: 6309, dtype: int64

# %%
morethan19Nulls = attacks_clean_Transp.isnull().sum()[attacks_clean_Transp.isnull().sum() > 19].index
morethan19Nulls
attacks_clean_Transp = attacks_clean_Transp.drop(columns=morethan19Nulls)
attacks_clean_Transp
# Out:
#                                                                      0     \
# Case Number                                                    2018.06.25
# Date                                                          25-Jun-2018
# Year                                                                 2018
# Type                                                              Boating
# Country                                                               USA
# Area                                                           California
# Location                                      Oceanside, San Diego County
# Activity                                                         Paddling
# Name                                                          Julie Wolfe
# Sex                                                                     F
# Age                                                                    57
# Injury                  No injury to occupant, outrigger canoe and pad...
# Fatal (Y/N)                                                             N
# Time                                                                18h00
# Species                                                       White shark
# Investigator or Source                                   R. Collier, GSAF
# pdf                                                  2018.06.25-Wolfe.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                  2018.06.25
# Case Number.2                                                  2018.06.25
# original order                                                       6303
#
#                                                                      1     \
# Case Number                                                    2018.06.18
# Date                                                          18-Jun-2018
# Year                                                                 2018
# Type                                                           Unprovoked
# Country                                                               USA
# Area                                                              Georgia
# Location                                   St. Simon Island, Glynn County
# Activity                                                         Standing
# Name                                                      Adyson McNeely
# Sex                                                                     F
# Age                                                                    11
# Injury                                         Minor injury to left thigh
# Fatal (Y/N)                                                             N
# Time                                                        14h00  -15h00
# Species                                                               NaN
# Investigator or Source                     K.McMurray, TrackingSharks.com
# pdf                                                2018.06.18-McNeely.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                  2018.06.18
# Case Number.2                                                  2018.06.18
# original order                                                       6302
#
#                                                                      2     \
# Case Number                                                    2018.06.09
# Date                                                          09-Jun-2018
# Year                                                                 2018
# Type                                                              Invalid
# Country                                                               USA
# Area                                                               Hawaii
# Location                                                     Habush, Oahu
# Activity                                                          Surfing
# Name                                                          John Denges
# Sex                                                                     M
# Age                                                                    48
# Injury                       Injury to left lower leg from surfboard skeg
# Fatal (Y/N)                                                             N
# Time                                                                07h45
# Species                                                               NaN
# Investigator or Source                     K.McMurray, TrackingSharks.com
# pdf                                                 2018.06.09-Denges.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                  2018.06.09
# Case Number.2                                                  2018.06.09
# original order                                                       6301
#
#                                                                      3     \
# Case Number                                                    2018.06.08
# Date                                                          08-Jun-2018
# Year                                                                 2018
# Type                                                           Unprovoked
# Country                                                         AUSTRALIA
# Area                                                      New South Wales
# Location                                               Arrawarra Headland
# Activity                                                          Surfing
# Name                                                                 male
# Sex                                                                     M
# Age                                                                   NaN
# Injury                                          Minor injury to lower leg
# Fatal (Y/N)                                                             N
# Time                                                                  NaN
# Species                                                         2 m shark
# Investigator or Source                                     B. Myatt, GSAF
# pdf                                              2018.06.08-Arrawarra.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                  2018.06.08
# Case Number.2                                                  2018.06.08
# original order                                                       6300
#
#                                                                      4     \
# Case Number                                                    2018.06.04
# Date                                                          04-Jun-2018
# Year                                                                 2018
# Type                                                             Provoked
# Country                                                            MEXICO
# Area                                                               Colima
# Location                                                         La Ticla
# Activity                                                      Free diving
# Name                                                       Gustavo Ramos
# Sex                                                                     M
# Age                                                                   NaN
# Injury                  Lacerations to leg & hand shark PROVOKED INCIDENT
# Fatal (Y/N)                                                             N
# Time                                                                  NaN
# Species                                                   Tiger shark, 3m
# Investigator or Source                                          A .Kipper
# pdf                                                  2018.06.04-Ramos.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                  2018.06.04
# Case Number.2                                                  2018.06.04
# original order                                                       6299
#
#                                                                      5     \
# Case Number                                                  2018.06.03.b
# Date                                                          03-Jun-2018
# Year                                                                 2018
# Type                                                           Unprovoked
# Country                                                         AUSTRALIA
# Area                                                      New South Wales
# Location                                               Flat Rock, Ballina
# Activity                                                     Kite surfing
# Name                                                              Chris
#
# Sex                                                                     M
# Age                                                                   NaN
# Injury                                            No injury, board bitten
# Fatal (Y/N)                                                             N
# Time                                                                  NaN
# Species                                                               NaN
# Investigator or Source                          Daily Telegraph, 6/4/2018
# pdf                                             2018.06.03.b-FlatRock.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                2018.06.03.b
# Case Number.2                                                2018.06.03.b
# original order                                                       6298
#
#                                                                      6     \
# Case Number                                                  2018.06.03.a
# Date                                                          03-Jun-2018
# Year                                                                 2018
# Type                                                           Unprovoked
# Country                                                            BRAZIL
# Area                                                           Pernambuco
# Location                                            Piedade Beach, Recife
# Activity                                                         Swimming
# Name                                               Jose Ernesto da Silva
# Sex                                                                     M
# Age                                                                    18
# Injury                                                              FATAL
# Fatal (Y/N)                                                             Y
# Time                                                       Late afternoon
# Species                                                       Tiger shark
# Investigator or Source                     Diario de Pernambuco, 6/4/2018
# pdf                                              2018.06.03.a-daSilva.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                2018.06.03.a
# Case Number.2                                                2018.06.03.a
# original order                                                       6297
#
#                                                                      7     \
# Case Number                                                    2018.05.27
# Date                                                          27-May-2018
# Year                                                                 2018
# Type                                                           Unprovoked
# Country                                                               USA
# Area                                                              Florida
# Location                Lighhouse Point Park, Ponce Inlet, Volusia County
# Activity                                                          Fishing
# Name                                                                 male
# Sex                                                                     M
# Age                                                                    52
# Injury                            Minor injury to foot. PROVOKED INCIDENT
# Fatal (Y/N)                                                             N
# Time                                                                  NaN
# Species                                                   Lemon shark, 3'
# Investigator or Source                    K. McMurray, TrackingSharks.com
# pdf                                                  2018.05.27-Ponce.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                  2018.05.27
# Case Number.2                                                  2018.05.27
# original order                                                       6296
#
#                                                                      8     \
# Case Number                                                  2018.05.26.b
# Date                                                          26-May-2018
# Year                                                                 2018
# Type                                                           Unprovoked
# Country                                                               USA
# Area                                                              Florida
# Location                                     Cocoa Beach, Brevard  County
# Activity                                                          Walking
# Name                                                            Cody High
# Sex                                                                     M
# Age                                                                    15
# Injury                                              Lower left leg bitten
# Fatal (Y/N)                                                             N
# Time                                                                17h00
# Species                                                    Bull shark, 6'
# Investigator or Source                     K.McMurray, TrackingSharks.com
# pdf                                                 2018.05.26.b-High.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                2018.05.26.b
# Case Number.2                                                2018.05.26.b
# original order                                                       6295
#
#                                                                      9     \
# Case Number                                                  2018.05.26.a
# Date                                                          26-May-2018
# Year                                                                 2018
# Type                                                           Unprovoked
# Country                                                               USA
# Area                                                              Florida
# Location                                    Daytona Beach, Volusia County
# Activity                                                         Standing
# Name                                                                 male
# Sex                                                                     M
# Age                                                                    12
# Injury                                               Minor injury to foot
# Fatal (Y/N)                                                             N
# Time                                                                14h00
# Species                                                               NaN
# Investigator or Source                   K. McMurray, Tracking Sharks.com
# pdf                                         2018.05.26.a-DaytonaBeach.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                2018.05.26.a
# Case Number.2                                                2018.05.26.a
# original order                                                       6294
#
#                         ...  \
# Case Number             ...
# Date                    ...
# Year                    ...
# Type                    ...
# Country                 ...
# Area                    ...
# Location                ...
# Activity                ...
# Name                    ...
# Sex                     ...
# Age                     ...
# Injury                  ...
# Fatal (Y/N)             ...
# Time                    ...
# Species                 ...
# Investigator or Source  ...
# pdf                     ...
# href formula            ...
# href                    ...
# Case Number.1           ...
# Case Number.2           ...
# original order          ...
#
#                                                                      6292  \
# Case Number                                                       ND.0010
# Date                                                           Circa 1862
# Year                                                                    0
# Type                                                           Unprovoked
# Country                                                               USA
# Area                                                               Hawaii
# Location                                                             Puna
# Activity                                                              NaN
# Name                                                         A "chiefess"
# Sex                                                                     F
# Age                                                                   NaN
# Injury                                                       Ankle bitten
# Fatal (Y/N)                                                             N
# Time                                                                  NaN
# Species                                                               NaN
# Investigator or Source                                   Captain W. Young
# pdf                                               ND-0010-Puna Hawaii.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                     ND.0010
# Case Number.2                                                     ND.0010
# original order                                                         11
#
#                                                                      6293  \
# Case Number                                                       ND.0009
# Date                                                          Before 1906
# Year                                                                    0
# Type                                                           Unprovoked
# Country                                                         AUSTRALIA
# Area                                                                  NaN
# Location                                                              NaN
# Activity                                                          Fishing
# Name                                                                  boy
# Sex                                                                     M
# Age                                                                   NaN
# Injury                  FATAL, knocked overboard by tail of shark & ca...
# Fatal (Y/N)                                                             Y
# Time                                                                  NaN
# Species                                                      Blue pointer
# Investigator or Source  NY Sun, 9/9/1906, referring to account by Loui...
# pdf                                             ND-0009-boy-Australia.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                     ND.0009
# Case Number.2                                                     ND.0009
# original order                                                         10
#
#                                                                      6294  \
# Case Number                                                       ND.0008
# Date                                                          Before 1906
# Year                                                                    0
# Type                                                           Unprovoked
# Country                                                         AUSTRALIA
# Area                                                                  NaN
# Location                                                              NaN
# Activity                                                          Fishing
# Name                                                            fisherman
# Sex                                                                     M
# Age                                                                   NaN
# Injury                                                              FATAL
# Fatal (Y/N)                                                             Y
# Time                                                                  NaN
# Species                                                      Blue pointer
# Investigator or Source  NY Sun, 9/9/1906, referring to account by Loui...
# pdf                                      ND-0008-Fisherman2-Australia.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                     ND.0008
# Case Number.2                                                     ND.0008
# original order                                                          9
#
#                                                                      6295  \
# Case Number                                                       ND.0007
# Date                                                          Before 1906
# Year                                                                    0
# Type                                                           Unprovoked
# Country                                                         AUSTRALIA
# Area                                                                  NaN
# Location                                                              NaN
# Activity                                                          Fishing
# Name                                                            fisherman
# Sex                                                                     M
# Age                                                                   NaN
# Injury                                                              FATAL
# Fatal (Y/N)                                                             Y
# Time                                                                  NaN
# Species                                                     Blue pointers
# Investigator or Source  NY Sun, 9/9/1906, referring to account by Loui...
# pdf                                     ND-0007 - Fisherman-Australia.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                     ND.0007
# Case Number.2                                                     ND.0007
# original order                                                          8
#
#                                                                      6296  \
# Case Number                                                       ND.0006
# Date                                                          Before 1906
# Year                                                                    0
# Type                                                           Unprovoked
# Country                                                         AUSTRALIA
# Area                                                      New South Wales
# Location
# Activity                                                         Swimming
# Name                                                             Arab boy
# Sex                                                                     M
# Age                                                                   NaN
# Injury                                                              FATAL
# Fatal (Y/N)                                                             Y
# Time                                                                  NaN
# Species                 Said to involve a grey nurse shark that leapt ...
# Investigator or Source  L. Becke in New York Sun, 9/9/1906; L. Schultz...
# pdf                                          ND-0006-ArabBoy-Prymount.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                     ND.0006
# Case Number.2                                                     ND.0006
# original order                                                          7
#
#                                                                      6297  \
# Case Number                                                       ND.0005
# Date                                                          Before 1903
# Year                                                                    0
# Type                                                           Unprovoked
# Country                                                         AUSTRALIA
# Area                                                    Western Australia
# Location                                                      Roebuck Bay
# Activity                                                           Diving
# Name                                                                 male
# Sex                                                                     M
# Age                                                                   NaN
# Injury                                                              FATAL
# Fatal (Y/N)                                                             Y
# Time                                                                  NaN
# Species                                                               NaN
# Investigator or Source                   H. Taunton; N. Bartlett,  p. 234
# pdf                                                ND-0005-RoebuckBay.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                     ND.0005
# Case Number.2                                                     ND.0005
# original order                                                          6
#
#                                                                      6298  \
# Case Number                                                       ND.0004
# Date                                                          Before 1903
# Year                                                                    0
# Type                                                           Unprovoked
# Country                                                         AUSTRALIA
# Area                                                    Western Australia
# Location                                                              NaN
# Activity                                                     Pearl diving
# Name                                                                Ahmun
# Sex                                                                     M
# Age                                                                   NaN
# Injury                                                              FATAL
# Fatal (Y/N)                                                             Y
# Time                                                                  NaN
# Species                                                               NaN
# Investigator or Source              H. Taunton; N. Bartlett,  pp. 233-234
# pdf                                                     ND-0004-Ahmun.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                     ND.0004
# Case Number.2                                                     ND.0004
# original order                                                          5
#
#                                                                      6299  \
# Case Number                                                       ND.0003
# Date                                                            1900-1905
# Year                                                                    0
# Type                                                           Unprovoked
# Country                                                               USA
# Area                                                       North Carolina
# Location                                                   Ocracoke Inlet
# Activity                                                         Swimming
# Name                                                Coast Guard personnel
# Sex                                                                     M
# Age                                                                   NaN
# Injury                                                              FATAL
# Fatal (Y/N)                                                             Y
# Time                                                                  NaN
# Species                                                               NaN
# Investigator or Source               F. Schwartz, p.23; C. Creswell, GSAF
# pdf                                        ND-0003-Ocracoke_1900-1905.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                     ND.0003
# Case Number.2                                                     ND.0003
# original order                                                          4
#
#                                                                      6300  \
# Case Number                                                       ND.0002
# Date                                                            1883-1889
# Year                                                                    0
# Type                                                           Unprovoked
# Country                                                            PANAMA
# Area                                                                  NaN
# Location                                             Panama Bay 8ºN, 79ºW
# Activity                                                              NaN
# Name                                                      Jules Patterson
# Sex                                                                     M
# Age                                                                   NaN
# Injury                                                              FATAL
# Fatal (Y/N)                                                             Y
# Time                                                                  NaN
# Species                                                               NaN
# Investigator or Source                                The Sun, 10/20/1938
# pdf                                            ND-0002-JulesPatterson.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                     ND.0002
# Case Number.2                                                     ND.0002
# original order                                                          3
#
#                                                                      6301
# Case Number                                                       ND.0001
# Date                                                            1845-1853
# Year                                                                    0
# Type                                                           Unprovoked
# Country                                                CEYLON (SRI LANKA)
# Area                                                     Eastern Province
# Location                              Below the English fort, Trincomalee
# Activity                                                         Swimming
# Name                                                                 male
# Sex                                                                     M
# Age                                                                    15
# Injury                  FATAL. "Shark bit him in half, carrying away t...
# Fatal (Y/N)                                                             Y
# Time                                                                  NaN
# Species                                                               NaN
# Investigator or Source                                         S.W. Baker
# pdf                                                    ND-0001-Ceylon.pdf
# href formula            http://sharkattackfile.net/spreadsheets/pdf_di...
# href                    http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                     ND.0001
# Case Number.2                                                     ND.0001
# original order                                                          2
#
# [22 rows x 6302 columns]

# %%
attacks_clean_Transp.isnull().sum().max()
# Out:
# 8

# %%
attacks_clean = attacks_clean_Transp.T
attacks_clean
# Out:
#      Case Number         Date  Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018    Provoked              MEXICO
# ...          ...          ...   ...         ...                 ...
# 6297     ND.0005  Before 1903     0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# 0            California          Oceanside, San Diego County      Paddling
# 1               Georgia       St. Simon Island, Glynn County      Standing
# 2                Hawaii                         Habush, Oahu       Surfing
# 3       New South Wales                   Arrawarra Headland       Surfing
# 4                Colima                             La Ticla   Free diving
# ...                 ...                                  ...           ...
# 6297  Western Australia                          Roebuck Bay        Diving
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6300                NaN                 Panama Bay 8ºN, 79ºW           NaN
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   ... Fatal (Y/N)           Time  \
# 0               Julie Wolfe    F  ...           N          18h00
# 1           Adyson McNeely     F  ...           N  14h00  -15h00
# 2               John Denges    M  ...           N          07h45
# 3                      male    M  ...           N            NaN
# 4            Gustavo Ramos     M  ...           N            NaN
# ...                     ...  ...  ...         ...            ...
# 6297                   male    M  ...           Y            NaN
# 6298                  Ahmun    M  ...           Y            NaN
# 6299  Coast Guard personnel    M  ...           Y            NaN
# 6300        Jules Patterson    M  ...           Y            NaN
# 6301                   male    M  ...           Y            NaN
#
#              Species                  Investigator or Source  \
# 0         White shark                       R. Collier, GSAF
# 1                 NaN         K.McMurray, TrackingSharks.com
# 2                 NaN         K.McMurray, TrackingSharks.com
# 3           2 m shark                         B. Myatt, GSAF
# 4     Tiger shark, 3m                              A .Kipper
# ...               ...                                    ...
# 6297              NaN       H. Taunton; N. Bartlett,  p. 234
# 6298              NaN  H. Taunton; N. Bartlett,  pp. 233-234
# 6299              NaN   F. Schwartz, p.23; C. Creswell, GSAF
# 6300              NaN                    The Sun, 10/20/1938
# 6301              NaN                             S.W. Baker
#
#                                  pdf  \
# 0               2018.06.25-Wolfe.pdf
# 1             2018.06.18-McNeely.pdf
# 2              2018.06.09-Denges.pdf
# 3           2018.06.08-Arrawarra.pdf
# 4               2018.06.04-Ramos.pdf
# ...                              ...
# 6297          ND-0005-RoebuckBay.pdf
# 6298               ND-0004-Ahmun.pdf
# 6299  ND-0003-Ocracoke_1900-1905.pdf
# 6300      ND-0002-JulesPatterson.pdf
# 6301              ND-0001-Ceylon.pdf
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                 ...           ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0002
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
#
#      Case Number.2 original order
# 0       2018.06.25           6303
# 1       2018.06.18           6302
# 2       2018.06.09           6301
# 3       2018.06.08           6300
# 4       2018.06.04           6299
# ...            ...            ...
# 6297       ND.0005              6
# 6298       ND.0004              5
# 6299       ND.0003              4
# 6300       ND.0002              3
# 6301       ND.0001              2
#
# [6302 rows x 22 columns]

# %%
attacks_clean.iloc[0]
# Out:
# Case Number                                                      2018.06.25
# Date                                                            25-Jun-2018
# Year                                                                   2018
# Type                                                                Boating
# Country                                                                 USA
# Area                                                             California
# Location                                        Oceanside, San Diego County
# Activity                                                           Paddling
# Name                                                            Julie Wolfe
# Sex                                                                       F
# Age                                                                      57
# Injury                    No injury to occupant, outrigger canoe and pad...
# Fatal (Y/N)                                                               N
# Time                                                                  18h00
# Species                                                         White shark
# Investigator or Source                                     R. Collier, GSAF
# pdf                                                    2018.06.25-Wolfe.pdf
# href formula              http://sharkattackfile.net/spreadsheets/pdf_di...
# href                      http://sharkattackfile.net/spreadsheets/pdf_di...
# Case Number.1                                                    2018.06.25
# Case Number.2                                                    2018.06.25
# original order                                                         6303
# Name: 0, dtype: object

# %% [markdown]
# Voy a echar un vistazo a las columnas Case Number, Case Number.1 y Case Number.2 que parece que contienen info similar

# %%
attack_clean2 = attacks_clean[["Case Number","Case Number.1","Case Number.2"]]

# %%
display(attack_clean2["Case Number"] == attack_clean2["Case Number.1"])
attack_clean2["Case Number.2"] == attack_clean2["Case Number.1"]
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 6297    True
# 6298    True
# 6299    True
# 6300    True
# 6301    True
# Length: 6302, dtype: bool
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 6297    True
# 6298    True
# 6299    True
# 6300    True
# 6301    True
# Length: 6302, dtype: bool

# %%
print(list(attack_clean2["Case Number"])==list(attack_clean2["Case Number.1"]))

print(list(attack_clean2["Case Number"])==list(attack_clean2["Case Number.2"]))
print(list(attack_clean2["Case Number.1"])==list(attack_clean2["Case Number.2"]))
# Out:
# False
# False
# False

# %%
count=0
for e in zip(list(attack_clean2["Case Number"]), list(attack_clean2["Case Number.1"]), list(attack_clean2["Case Number.2"])):
    if (e[0]!=e[1]) | (e[0]!=e[2]) | (e[2]!=e[1]): 
        count+=1
print(count)
# Out:
# 24

# %%
attacks_clean["Date"].value_counts()
# Out:
# 1957                    11
# 1942                     9
# 1956                     8
# 1950                     7
# 1941                     7
#                         ..
# 24-Oct-2016              1
# 11-Aug-1968              1
# 04-Feb-2001              1
# Reported 26-Jun-1959     1
#  14-Aug-2013             1
# Name: Date, Length: 5433, dtype: int64

# %%
attacks_clean["Year"].value_counts()
# Out:
# 2015.0    143
# 2017.0    136
# 2016.0    130
# 2011.0    128
# 2014.0    127
#          ...
# 1786.0      1
# 1785.0      1
# 1784.0      1
# 1783.0      1
# 1834.0      1
# Name: Year, Length: 249, dtype: int64

# %% [markdown]
# Creoq ue solo me voy a quedar con year, borro date y los cases numbers

# %%
attack_clean3 = attacks_clean[["Case Number","Case Number.1","Case Number.2", "Year", "Date"]]

#función quedarme solo con años
def fn(value):
    return (str(value))[0:4]

attack_clean3["Case Number_mod"] = attack_clean3["Case Number"].apply(fn)
attack_clean3["Case Number.1_mod"] = attack_clean3["Case Number.1"].apply(fn)
attack_clean3["Case Number.2_mod"] = attack_clean3["Case Number.2"].apply(fn)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
attack_clean3
# Out:
#      Case Number Case Number.1 Case Number.2  Year         Date  \
# 0     2018.06.25    2018.06.25    2018.06.25  2018  25-Jun-2018
# 1     2018.06.18    2018.06.18    2018.06.18  2018  18-Jun-2018
# 2     2018.06.09    2018.06.09    2018.06.09  2018  09-Jun-2018
# 3     2018.06.08    2018.06.08    2018.06.08  2018  08-Jun-2018
# 4     2018.06.04    2018.06.04    2018.06.04  2018  04-Jun-2018
# ...          ...           ...           ...   ...          ...
# 6297     ND.0005       ND.0005       ND.0005     0  Before 1903
# 6298     ND.0004       ND.0004       ND.0004     0  Before 1903
# 6299     ND.0003       ND.0003       ND.0003     0    1900-1905
# 6300     ND.0002       ND.0002       ND.0002     0    1883-1889
# 6301     ND.0001       ND.0001       ND.0001     0    1845-1853
#
#      Case Number_mod Case Number.1_mod Case Number.2_mod
# 0               2018              2018              2018
# 1               2018              2018              2018
# 2               2018              2018              2018
# 3               2018              2018              2018
# 4               2018              2018              2018
# ...              ...               ...               ...
# 6297            ND.0              ND.0              ND.0
# 6298            ND.0              ND.0              ND.0
# 6299            ND.0              ND.0              ND.0
# 6300            ND.0              ND.0              ND.0
# 6301            ND.0              ND.0              ND.0
#
# [6302 rows x 8 columns]

# %%
attack_clean3 = attack_clean3.drop(columns=["Case Number","Case Number.1","Case Number.2"])

# %%
#attack_clean3["Date_mod"] = attack_clean3["Date"].fillna("No")
attack_clean3["Date_mod"] = attack_clean3["Date"]

# %%
def fn2(value):
    a = re.search(r"\d{4}.*", value)
    if a!=None: # Hago esto porque me estaba devolviendo error al hacer el group()
        b = a.group()
        return b
    else:
        return a

    
attack_clean3["Date_mod2"] = attack_clean3["Date_mod"].apply(fn2)
attack_clean3["Date_mod2"]
# Out:
# 0            2018
# 1            2018
# 2            2018
# 3            2018
# 4            2018
#           ...
# 6297         1903
# 6298         1903
# 6299    1900-1905
# 6300    1883-1889
# 6301    1845-1853
# Name: Date_mod2, Length: 6302, dtype: object

# %%
attack_clean3 = attack_clean3.drop(columns=["Date","Date_mod"])
attack_clean3
# Out:
#       Year Case Number_mod Case Number.1_mod Case Number.2_mod  Date_mod2
# 0     2018            2018              2018              2018       2018
# 1     2018            2018              2018              2018       2018
# 2     2018            2018              2018              2018       2018
# 3     2018            2018              2018              2018       2018
# 4     2018            2018              2018              2018       2018
# ...    ...             ...               ...               ...        ...
# 6297     0            ND.0              ND.0              ND.0       1903
# 6298     0            ND.0              ND.0              ND.0       1903
# 6299     0            ND.0              ND.0              ND.0  1900-1905
# 6300     0            ND.0              ND.0              ND.0  1883-1889
# 6301     0            ND.0              ND.0              ND.0  1845-1853
#
# [6302 rows x 5 columns]
